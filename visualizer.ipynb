# %%
# %matplotlib notebook
from draw_tool import *
from kd_tree import KDTree

points = [
    (1, 1),
    (1, 2),
    (1, 3),
    (2, 1),
    (2, 2),
    (2, 3),
    (3, 1),
    (3, 2),
    (3, 3)
]
tree = KDTree(points)
points, scenes = tree.search(1.6, 2.4, 1.6, 2.4, True)
plot = Plot(scenes)
plot.draw()
print(points)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(2, 2)]
