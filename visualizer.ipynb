# %% [markdown]
# # Project - quadtree and kd-tree

# %% [markdown]
# ## Necessary imports

# %%
from draw_tool import *
from kd_tree import KDTree
from quadtree import Quadtree
from geometry import Point, Rectangle
from typing import List
from gen_data import *

# %% [markdown]
# ## Generating a test

# %%
test_points: List[Point] = gen_points(scope=(0, 150), n=30)
test_rectangle: Rectangle = Rectangle(-20, 60, 10, 80)

# %% [markdown]
# ## kd-tree - visualization on a sample test

# %% [markdown]
# ### Building the kd-tree

# %%
# %matplotlib notebook

kd_tree = KDTree(test_points)
kd_tree_plot = Plot([kd_tree.get_visualized()])
kd_tree_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Running the test

# %%
# %matplotlib notebook

min_x, max_x, min_y, max_y = test_rectangle.to_tuple()
points, scenes = kd_tree.search(min_x, max_x, min_y, max_y, visualize=True)
kd_tree_search_plot = Plot(scenes)
kd_tree_search_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## quadtree - visualization on a sample test

# %%
# %matplotlib notebook
quadtree = Quadtree(test_points)
rect = Rectangle(min_x, max_x, min_y, max_y)
quadtree_find_plot = quadtree.find(rect, True)
quadtree_find_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
