# %%
# %matplotlib notebook
from draw_tool import *
from kd_tree import KDTree

points = [
    (1, 1),
    (1, 2),
    (1, 3),
    (2, 1),
    (2, 2),
    (2, 3),
    (3, 1),
    (3, 2),
    (3, 3)
]
tree = KDTree(points)
plot = Plot([tree.get_visualized()])
plot.draw()
print(tree.search(1.3, 1.6, 1.3, 1.6))
# Out:
# <img src="data:image/png;base64,..." width="640">
# []
